# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
URL_DATA = '/content/drive/MyDrive/AI-Discovery-of-Unknown-Multi-Disease-Phenotypes-in-Longitudinal-Electronic-Health-Records/physionet.org/files/mimic-iv-demo/2.2/'
URL_PROJECT = '/content/drive/MyDrive/AI-Discovery-of-Unknown-Multi-Disease-Phenotypes-in-Longitudinal-Electronic-Health-Records/'

# %%
df_pheno_patients = pd.read_csv(URL_PROJECT+'pheno_physical.csv').drop(['Unnamed: 0'],axis=1)
df_pheno_marker = pd.read_csv(URL_PROJECT+'marker_cluster_of_patients.csv').drop(['Unnamed: 0'],axis=1)

# %%
df_pheno_marker
# Out:
#         hadm_id  mean_item_50802_Base_Excess  \
# 0    20044587.0                     0.181818
# 1    20093566.0                    -1.500000
# 2    20192635.0                          NaN
# 3    20199380.0                          NaN
# 4    20214994.0                   -10.375000
# ..          ...                          ...
# 247  29820177.0                          NaN
# 248  29839885.0                          NaN
# 249  29842315.0                          NaN
# 250  29858644.0                          NaN
# 251  29974575.0                    -1.727273
#
#      mean_item_50804_Calculated_Total_CO2  mean_item_50808_Free_Calcium  \
# 0                               25.181818                      1.174444
# 1                               25.000000                           NaN
# 2                                     NaN                           NaN
# 3                                     NaN                      1.040000
# 4                               15.937500                      1.130000
# ..                                    ...                           ...
# 247                                   NaN                           NaN
# 248                                   NaN                           NaN
# 249                                   NaN                           NaN
# 250                                   NaN                           NaN
# 251                             26.090909                           NaN
#
#      mean_item_50809_Glucose  mean_item_50813_Lactate  \
# 0                 120.142857                 1.950000
# 1                        NaN                 1.950000
# 2                        NaN                      NaN
# 3                 137.000000                 0.900000
# 4                 132.666667                 6.920000
# ..                       ...                      ...
# 247                      NaN                      NaN
# 248                      NaN                      NaN
# 249                      NaN                 2.150000
# 250                      NaN                      NaN
# 251                      NaN                 1.183333
#
#      mean_item_50817_Oxygen_Saturation  mean_item_50818_pCO2  \
# 0                                 96.5             38.181818
# 1                                  NaN             42.500000
# 2                                  NaN                   NaN
# 3                                  NaN                   NaN
# 4                                 80.0             33.437500
# ..                                 ...                   ...
# 247                                NaN                   NaN
# 248                                NaN                   NaN
# 249                               55.0                   NaN
# 250                                NaN                   NaN
# 251                                NaN             50.090909
#
#      mean_item_50820_pH  mean_item_50821_pO2  ...  std_item_51256_Neutrophils  \
# 0              7.415385           222.272727  ...                         NaN
# 1              7.350000           152.000000  ...                         NaN
# 2                   NaN                  NaN  ...                         NaN
# 3              7.370000                  NaN  ...                         NaN
# 4              7.260625           141.625000  ...                   13.930004
# ..                  ...                  ...  ...                         ...
# 247                 NaN                  NaN  ...                         NaN
# 248                 NaN                  NaN  ...                         NaN
# 249                 NaN                  NaN  ...                         NaN
# 250                 NaN                  NaN  ...                         NaN
# 251            7.314545            87.090909  ...                    8.226178
#
#      std_item_51265_Platelet_Count  std_item_51274_PT  std_item_51275_PTT  \
# 0                        40.584144           1.275931            0.882610
# 1                         5.291503           0.287228            1.436141
# 2                        28.284271                NaN                 NaN
# 3                        32.491482           0.311448           32.017333
# 4                        34.491929           3.958114            8.096451
# ..                             ...                ...                 ...
# 247                       6.658328                NaN                 NaN
# 248                            NaN                NaN                 NaN
# 249                      19.014562           1.830642           20.519476
# 250                      13.500000           0.424264            1.060660
# 251                      53.568263           0.832809            8.625699
#
#      std_item_51277_RDW  std_item_51279_Red_Blood_Cells  \
# 0              0.358569                        0.231254
# 1              0.353553                        0.158623
# 2              0.070711                        0.155563
# 3              0.140789                        0.396485
# 4              0.936916                        0.486037
# ..                  ...                             ...
# 247            0.251661                        0.162583
# 248                 NaN                             NaN
# 249            0.192725                        0.413660
# 250            0.057735                        0.200832
# 251            0.424264                        0.180176
#
#      std_item_51301_White_Blood_Cells  std_item_51678_L  \
# 0                            2.058389               NaN
# 1                            1.041367          1.214986
# 2                            2.192031               NaN
# 3                            1.753975          5.000000
# 4                            2.214168               NaN
# ..                                ...               ...
# 247                          0.264575               NaN
# 248                               NaN               NaN
# 249                          1.913673          2.725541
# 250                          0.607591               NaN
# 251                          1.996946               NaN
#
#      std_item_52172_RDW-SD  marker_cluster
# 0                      NaN               0
# 1                 1.421267               1
# 2                      NaN               2
# 3                 0.882266               2
# 4                      NaN               2
# ..                     ...             ...
# 247                    NaN               2
# 248                    NaN               2
# 249               0.796421               1
# 250                    NaN               2
# 251                    NaN               2
#
# [252 rows x 113 columns]

# %%
df_pheno_marker_merge = pd.merge(df_pheno_patients, df_pheno_marker, on='hadm_id', how='inner')

# %%
df_pheno_marker_merge
# Out:
#      subject_id   hadm_id  approx_age  gender  num_diagnoses  length_of_stay  \
# 0      10004235  24181354          47       0             26        8.975000
# 1      10009628  25926192          58       0              8        7.841667
# 2      10018081  23983182          79       0             19        5.731250
# 3      10006053  22942076          52       0             10        1.736806
# 4      10031404  21606243          82       1             15        2.090972
# ..          ...       ...         ...     ...            ...             ...
# 247    10038992  24745425          70       0             17        5.664583
# 248    10008287  22168393          43       1              3        4.512500
# 249    10022880  27708593          66       0              9        7.298611
# 250    10004457  23251352          65       0             11        4.205556
# 251    10004457  28108313          65       0             10        2.673611
#
#      died_in_hospital  cluster  mean_item_50802_Base_Excess  \
# 0                   0        2                    -8.653846
# 1                   0        2                     0.272727
# 2                   0        2                          NaN
# 3                   1        3                   -11.250000
# 4                   0        4                          NaN
# ..                ...      ...                          ...
# 247                 0        2                     4.142857
# 248                 0        1                    -1.000000
# 249                 0        2                     1.000000
# 250                 0        2                     2.142857
# 251                 0        2                          NaN
#
#      mean_item_50804_Calculated_Total_CO2  ...  std_item_51256_Neutrophils  \
# 0                               17.384615  ...                         NaN
# 1                               25.909091  ...                         NaN
# 2                                     NaN  ...                         NaN
# 3                               17.000000  ...                         NaN
# 4                                     NaN  ...                         NaN
# ..                                    ...  ...                         ...
# 247                             30.000000  ...                         NaN
# 248                             23.500000  ...                         NaN
# 249                             26.000000  ...                         NaN
# 250                             27.142857  ...                         NaN
# 251                                   NaN  ...                         NaN
#
#      std_item_51265_Platelet_Count  std_item_51274_PT  std_item_51275_PTT  \
# 0                        54.487565           0.890454            3.838417
# 1                        47.022453          14.009412           35.205259
# 2                        75.640157           0.797392            2.721978
# 3                        24.784788           4.364937           55.435849
# 4                         4.949747                NaN                 NaN
# ..                             ...                ...                 ...
# 247                      20.461346           1.023067            1.457166
# 248                      12.020815                NaN                 NaN
# 249                      27.292943           2.550882            1.458424
# 250                      31.200962           2.211334            2.386071
# 251                            NaN                NaN                 NaN
#
#      std_item_51277_RDW  std_item_51279_Red_Blood_Cells  \
# 0              0.252125                        0.404013
# 1              0.502494                        0.601549
# 2              0.241523                        0.264258
# 3              0.464451                        0.239653
# 4              0.000000                        0.360624
# ..                  ...                             ...
# 247            0.294392                        0.197966
# 248            0.141421                        0.021213
# 249            0.177281                        0.316491
# 250            0.327109                        0.309349
# 251                 NaN                             NaN
#
#      std_item_51301_White_Blood_Cells  std_item_51678_L  \
# 0                            4.329465               NaN
# 1                            1.573037               NaN
# 2                            1.653145               NaN
# 3                            2.993565               NaN
# 4                            3.040559          2.828427
# ..                                ...               ...
# 247                          2.805776          3.399054
# 248                          0.707107               NaN
# 249                          1.253946               NaN
# 250                          1.874033               NaN
# 251                               NaN               NaN
#
#      std_item_52172_RDW-SD  marker_cluster
# 0                      NaN               2
# 1                      NaN               0
# 2                      NaN               2
# 3                      NaN               2
# 4                 0.636396               2
# ..                     ...             ...
# 247               1.697056              -1
# 248               1.343503               2
# 249               1.112055               2
# 250                    NaN               0
# 251                    NaN               2
#
# [252 rows x 120 columns]

# %%
cross_tab=pd.crosstab(df_pheno_marker_merge['cluster'], df_pheno_marker_merge['marker_cluster'])

# %%
cross_tab
# Out:
# marker_cluster  -1   0   1   2
# cluster
# 0                7   0   3  27
# 1                3   2   4  35
# 2                7  15   4  72
# 3                1   0   2  12
# 4               14   0   4  40

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.heatmap(cross_tab, annot=True, fmt='d', cmap='viridis')
plt.title("Phenotype vs Biomarker Cluster Count")
plt.xlabel("Biomarker Cluster")
plt.ylabel("Clinical Phenotype Cluster")
plt.tight_layout()
plt.show()

# %%
sns.boxplot(data=df_pheno_marker_merge, x='marker_cluster', y='approx_age')
plt.title("Length of Stay by Biomarker Cluster")
plt.show()

# %%
from scipy.stats import kruskal
import pandas as pd

cluster_col = 'marker_cluster'

# Step 1: Select only clinical phenotype columns (exclude clusters and IDs)
clinical_cols = [
    col for col in df_pheno_marker_merge.columns
    if col != cluster_col and
       df_pheno_marker_merge[col].dtype != 'O' and  # Exclude object (string) types
       col not in ['harm_id', 'pheno-cluster']
]

# Step 2: Run Kruskal-Wallis test for each phenotype
results = []

for feature in clinical_cols:
    temp_df = df_pheno_marker_merge[[cluster_col, feature]].dropna()
    groups = [group[feature].values for _, group in temp_df.groupby(cluster_col)]

    # Only test if there are at least 2 valid groups with more than 1 sample each
    if len(groups) >= 2 and all(len(g) > 1 for g in groups):
        stat, p = kruskal(*groups)
        results.append({'feature': feature, 'H_statistic': stat, 'p_value': p})

# Step 3: Compile and sort results
results_df = pd.DataFrame(results).sort_values('p_value')

# Display top results
print(results_df.head(10))
# Out:
#                            feature  H_statistic       p_value
# 28      mean_item_50912_Creatinine    44.590171  1.130729e-09
# 15             mean_item_50821_pO2    40.002806  1.064051e-08
# 70              std_item_50821_pO2    39.964779  1.083984e-08
# 35   mean_item_51006_Urea_Nitrogen    36.206325  6.772706e-08
# 20       mean_item_50868_Anion_Gap    36.096451  7.144876e-08
# 80       std_item_50912_Creatinine    35.466989  9.706401e-08
# 32       mean_item_50970_Phosphate    33.020692  3.188468e-07
# 89       std_item_51222_Hemoglobin    29.633880  1.647767e-06
# 98  std_item_51279_Red_Blood_Cells    29.015835  2.222337e-06
# 52             mean_item_51277_RDW    27.698979  4.200700e-06

# %%
top_features = results_df['feature'].head(3).tolist()

import matplotlib.pyplot as plt
import seaborn as sns

for feat in top_features:
    plt.figure(figsize=(8, 4))
    sns.boxplot(data=df_pheno_marker_merge, x='marker_cluster', y=feat)
    plt.title(f'Distribution of {feat} by Biomarker Cluster')
    plt.show()

# %%
unique_values, counts = np.unique(df_pheno_marker_merge['subject_id'], return_counts=True)

# %%
ts_subject_id = np.array([])
for count, id in zip(counts, unique_values):
  if count > 1:
    ts_subject_id = np.append(ts_subject_id, id)

# %%
df_timeseries_patient = df_pheno_marker_merge[df_pheno_marker_merge['subject_id'].isin(ts_subject_id)].drop(['marker_cluster','cluster'],axis=1)

# %%
import ts2vec

# %%
df_timeseries_patient[df_timeseries_patient['subject_id']==ts_subject_id[-1]]
# Out:
#      subject_id   hadm_id  approx_age  gender  num_diagnoses  length_of_stay  \
# 48     10040025  25933959          64       1             24       10.918056
# 134    10040025  25172300          64       1             28        1.590972
# 135    10040025  25384176          64       1             18        4.605556
# 136    10040025  27876215          64       1             30        5.452083
# 137    10040025  27553957          64       1             24        6.800000
# 218    10040025  21791856          64       1             28        5.760417
# 219    10040025  22251969          64       1             29        3.577778
# 220    10040025  27259207          64       1             30       13.829861
# 221    10040025  27996267          64       1             39       12.356250
# 232    10040025  27125816          64       1              9        0.976389
#
#      died_in_hospital  mean_item_50802_Base_Excess  \
# 48                  0                          NaN
# 134                 0                          NaN
# 135                 0                          NaN
# 136                 0                          NaN
# 137                 0                          NaN
# 218                 0                          NaN
# 219                 0                          NaN
# 220                 0                          NaN
# 221                 0                         -0.5
# 232                 0                          NaN
#
#      mean_item_50804_Calculated_Total_CO2  mean_item_50808_Free_Calcium  ...  \
# 48                                    NaN                           NaN  ...
# 134                                   NaN                           NaN  ...
# 135                                   NaN                           NaN  ...
# 136                                   NaN                           NaN  ...
# 137                                   NaN                           NaN  ...
# 218                                   NaN                           NaN  ...
# 219                                   NaN                           NaN  ...
# 220                                   NaN                           NaN  ...
# 221                                  27.0                          1.07  ...
# 232                                   NaN                           NaN  ...
#
#      std_item_51254_Monocytes  std_item_51256_Neutrophils  \
# 48                        NaN                         NaN
# 134                       NaN                         NaN
# 135                       NaN                         NaN
# 136                       NaN                         NaN
# 137                       NaN                         NaN
# 218                       NaN                         NaN
# 219                       NaN                         NaN
# 220                       NaN                         NaN
# 221                   2.12132                    4.949747
# 232                       NaN                         NaN
#
#      std_item_51265_Platelet_Count  std_item_51274_PT  std_item_51275_PTT  \
# 48                       37.745078                NaN                 NaN
# 134                            NaN           2.828427                 NaN
# 135                       7.325754           4.446722            0.424264
# 136                      24.903703           2.333452            2.757716
# 137                      25.192592           2.621259                 NaN
# 218                      13.541295           6.353162                 NaN
# 219                      12.841988           9.226953            3.439477
# 220                      44.288448           0.497996            1.156287
# 221                      56.633935          11.214417            6.645617
# 232                            NaN                NaN                 NaN
#
#      std_item_51277_RDW  std_item_51279_Red_Blood_Cells  \
# 48             0.122103                        0.212479
# 134                 NaN                             NaN
# 135            0.095743                        0.104881
# 136            0.918483                        0.132947
# 137            0.151186                        0.172599
# 218            0.054772                        0.095429
# 219            0.095743                        0.058023
# 220            0.280476                        0.101915
# 221            0.401755                        0.285850
# 232                 NaN                             NaN
#
#      std_item_51301_White_Blood_Cells  std_item_51678_L  std_item_52172_RDW-SD
# 48                           1.503390          4.543441               0.840022
# 134                               NaN               NaN                    NaN
# 135                          0.386221               NaN                    NaN
# 136                          1.325183          2.863564               1.464108
# 137                          1.110127               NaN                    NaN
# 218                          1.887238          2.898275               0.348807
# 219                          1.347838          2.121320               0.780491
# 220                          0.668331          3.359422               1.217648
# 221                          2.221695          2.717362               1.869469
# 232                               NaN               NaN                    NaN
#
# [10 rows x 118 columns]

# %%
df_labevents = pd.read_csv(URL_DATA+'hosp/labevents.csv.gz')

# %%
df_timeseries_patient = pd.merge(df_timeseries_patient, df_labevents[['charttime', 'hadm_id']])
df_microb = pd.read_csv(URL_DATA+'hosp/microbiologyevents.csv.gz')


df_timeseries_patient = pd.merge(df_timeseries_patient,df_microb)

# %%
groups = df_timeseries_patient.groupby('subject_id')

sequences = []
for subject_id, group in groups:
  sorted_group = group.sort_values('charttime')
  features = sorted_group.drop(['subject_id', 'hadm_id','charttime','chartdate'],axis=1)
  sequences.append(features)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

padded = pad_sequences(sequences, padding='post', dtype='float32')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-118-796347845.py in <cell line: 0>()
#       1 from tensorflow.keras.preprocessing.sequence import pad_sequences
#       2
# ----> 3 padded = pad_sequences(sequences, padding='post', dtype='float32')
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/sequence_utils.py in pad_sequences(sequences, maxlen, dtype, padding, truncating, value)
#     123
#     124         # check `trunc` has expected shape
# --> 125         trunc = np.asarray(trunc, dtype=dtype)
#     126         if trunc.shape[1:] != sample_shape:
#     127             raise ValueError(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __array__(self, dtype, copy)
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#
# ValueError: could not convert string to float: 'URINE'

# %%
padded.shape
# Out:
# (46, 7031, 116)

# %%
import gc
import torch

gc.collect()
torch.cuda.empty_cache()

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
from ts2vec import TS2Vec
import torch

model = TS2Vec(input_dims=padded.shape[-1], device='cuda',batch_size=16)

MAX_LEN = 512
padded = padded[:, :MAX_LEN, :]
model.fit(padded)

embeddings = model.encode(padded, encoding_window='full_series')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-85-446011171.py in <cell line: 0>()
#       6 MAX_LEN = 512
#       7 padded = padded[:, :MAX_LEN, :]
# ----> 8 model.fit(padded)
#       9
#      10 embeddings = model.encode(padded, encoding_window='full_series')
#
# /usr/local/lib/python3.11/dist-packages/ts2vec/ts2vec.py in fit(self, train_data, n_epochs, n_iters, verbose)
#     128                 out2 = out2[:, :crop_l]
#     129
# --> 130                 loss = hierarchical_contrastive_loss(
#     131                     out1,
#     132                     out2,
#
# /usr/local/lib/python3.11/dist-packages/ts2vec/models/losses.py in hierarchical_contrastive_loss(z1, z2, alpha, temporal_unit)
#      11         if d >= temporal_unit:
#      12             if 1 - alpha != 0:
# ---> 13                 loss += (1 - alpha) * temporal_contrastive_loss(z1, z2)
#      14         d += 1
#      15         z1 = F.max_pool1d(z1.transpose(1, 2), kernel_size=2).transpose(1, 2)
#
# /usr/local/lib/python3.11/dist-packages/ts2vec/models/losses.py in temporal_contrastive_loss(z1, z2)
#      41         return z1.new_tensor(0.)
#      42     z = torch.cat([z1, z2], dim=1)  # B x 2T x C
# ---> 43     sim = torch.matmul(z, z.transpose(1, 2))  # B x 2T x 2T
#      44     logits = torch.tril(sim, diagonal=-1)[:, :, :-1]    # B x 2T x (2T-1)
#      45     logits += torch.triu(sim, diagonal=1)[:, :, 1:]
#
# KeyboardInterrupt:

# %%
import hdbscan

clusterer = hdbscan.HDBSCAN(min_cluster_size=5)
labels = clusterer.fit_predict(embeddings)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
from umap import UMAP
import matplotlib.pyplot as plt

umap_proj = UMAP(n_components=2, random_state=42).fit_transform(embeddings)

plt.figure(figsize=(8,6))
plt.scatter(umap_proj[:,0], umap_proj[:,1], c=labels, cmap='tab10', s=60)
plt.title('UMAP projection of TS2Vec embeddings colored by HDBSCAN clusters')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
df_temporal_cluster = pd.DataFrame({
    'subject_id':df_timeseries_patient['subject_id'].unique(),
    'temporal_cluster':labels,
})

# %%
df_timeseries_patient = df_timeseries_patient.merge(df_temporal_cluster, on='subject_id')

# %%
df_timeseries_patient=df_timeseries_patient.drop(['temporal_cluster_x','temporal_cluster_y'],axis=1)

# %%
df_summary = df_timeseries_patient.drop(columns=['hadm_id', 'charttime']).groupby('subject_id').mean().reset_index()

# Now merge in cluster labels
df_summary = df_summary.merge(df_temporal_cluster, on='subject_id')

# %%
df_summary=df_summary.drop(['temporal_cluster_x'],axis=1)
df_summary['temporal_cluster']=df_summary['temporal_cluster_y']
df_summary=df_summary.drop(['temporal_cluster_y'], axis=1)

# %%
df_summary[df_summary['temporal_cluster'] == 0].drop(columns=['subject_id', 'temporal_cluster']).describe().to_csv(URL_PROJECT+'Temporal-Analysis-cluster-0')
df_summary[df_summary['temporal_cluster'] == 1].drop(columns=['subject_id', 'temporal_cluster']).describe().to_csv(URL_PROJECT+'Temporal-Analysis-cluster-1')

# %%
df_summary[df_summary['temporal_cluster'] == 0].drop(columns=['subject_id', 'temporal_cluster']).describe()
# Out:
#        approx_age     gender  num_diagnoses  length_of_stay  died_in_hospital  \
# count   15.000000  15.000000      15.000000       15.000000         15.000000
# mean    65.533333   0.400000      18.627859       12.077379          0.120289
# std     20.604669   0.507093       7.005971        9.812525          0.257389
# min     21.000000   0.000000       7.044248        1.863429          0.000000
# 25%     51.500000   0.000000      12.753747        6.872723          0.000000
# 50%     65.000000   0.000000      21.322862        8.337135          0.000000
# 75%     83.500000   1.000000      24.498531       14.605531          0.000000
# max     91.000000   1.000000      26.061162       41.055148          0.718654
#
#        mean_item_50802_Base_Excess  mean_item_50804_Calculated_Total_CO2  \
# count                    13.000000                             13.000000
# mean                     -1.084478                             25.102027
# std                       3.322938                              4.625463
# min                      -7.853823                             18.178026
# 25%                      -2.500000                             23.000000
# 50%                      -1.363636                             24.818182
# 75%                       1.100000                             26.500000
# max                       5.625000                             37.375000
#
#        mean_item_50808_Free_Calcium  mean_item_50809_Glucose  \
# count                     11.000000                 9.000000
# mean                       1.127519               130.459699
# std                        0.046010                22.255629
# min                        1.082228                96.666667
# 25%                        1.089241               118.769231
# 50%                        1.100000               130.409091
# 75%                        1.163646               143.000000
# max                        1.200000               171.000000
#
#        mean_item_50813_Lactate  ...  std_item_51254_Monocytes  \
# count                14.000000  ...                  6.000000
# mean                  2.121915  ...                  1.808588
# std                   0.823999  ...                  0.740197
# min                   0.900000  ...                  0.709460
# 25%                   1.712213  ...                  1.419821
# 50%                   2.121429  ...                  1.874105
# 75%                   2.391111  ...                  2.191304
# max                   4.150000  ...                  2.828427
#
#        std_item_51256_Neutrophils  std_item_51265_Platelet_Count  \
# count                    6.000000                      15.000000
# mean                     6.530005                      54.635029
# std                      4.220080                      46.518162
# min                      1.792577                      16.202214
# 25%                      3.342667                      28.176753
# 50%                      6.191047                      42.362672
# 75%                      8.748802                      52.102988
# max                     13.010765                     192.629103
#
#        std_item_51274_PT  std_item_51275_PTT  std_item_51277_RDW  \
# count          14.000000           14.000000           15.000000
# mean            1.916068           10.803080            0.388835
# std             1.565915           10.070460            0.216628
# min             0.282843            1.305435            0.180787
# 25%             0.801653            2.516722            0.237107
# 50%             1.396053            6.819204            0.321906
# 75%             2.382681           18.567885            0.453849
# max             4.843386           28.621427            0.956591
#
#        std_item_51279_Red_Blood_Cells  std_item_51301_White_Blood_Cells  \
# count                       15.000000                         15.000000
# mean                         0.329548                          2.908617
# std                          0.105034                          1.342626
# min                          0.171330                          0.837627
# 25%                          0.276261                          2.024934
# 50%                          0.325521                          3.051706
# 75%                          0.387411                          3.419497
# max                          0.533937                          6.419289
#
#        std_item_51678_L  std_item_52172_RDW-SD
# count          5.000000               7.000000
# mean           4.637135               1.177630
# std            3.501656               0.552822
# min            2.380740               0.412501
# 25%            2.412731               0.888626
# 50%            2.427815               1.098512
# 75%            5.558647               1.421400
# max           10.405740               2.112347
#
# [8 rows x 116 columns]

# %%
df_summary[df_summary['temporal_cluster'] == 0].drop(columns=['subject_id', 'temporal_cluster']).describe()
# Out:
#        approx_age     gender  num_diagnoses  length_of_stay  died_in_hospital  \
# count   15.000000  15.000000      15.000000       15.000000         15.000000
# mean    65.533333   0.400000      18.627859       12.077379          0.120289
# std     20.604669   0.507093       7.005971        9.812525          0.257389
# min     21.000000   0.000000       7.044248        1.863429          0.000000
# 25%     51.500000   0.000000      12.753747        6.872723          0.000000
# 50%     65.000000   0.000000      21.322862        8.337135          0.000000
# 75%     83.500000   1.000000      24.498531       14.605531          0.000000
# max     91.000000   1.000000      26.061162       41.055148          0.718654
#
#        mean_item_50802_Base_Excess  mean_item_50804_Calculated_Total_CO2  \
# count                    13.000000                             13.000000
# mean                     -1.084478                             25.102027
# std                       3.322938                              4.625463
# min                      -7.853823                             18.178026
# 25%                      -2.500000                             23.000000
# 50%                      -1.363636                             24.818182
# 75%                       1.100000                             26.500000
# max                       5.625000                             37.375000
#
#        mean_item_50808_Free_Calcium  mean_item_50809_Glucose  \
# count                     11.000000                 9.000000
# mean                       1.127519               130.459699
# std                        0.046010                22.255629
# min                        1.082228                96.666667
# 25%                        1.089241               118.769231
# 50%                        1.100000               130.409091
# 75%                        1.163646               143.000000
# max                        1.200000               171.000000
#
#        mean_item_50813_Lactate  ...  std_item_51254_Monocytes  \
# count                14.000000  ...                  6.000000
# mean                  2.121915  ...                  1.808588
# std                   0.823999  ...                  0.740197
# min                   0.900000  ...                  0.709460
# 25%                   1.712213  ...                  1.419821
# 50%                   2.121429  ...                  1.874105
# 75%                   2.391111  ...                  2.191304
# max                   4.150000  ...                  2.828427
#
#        std_item_51256_Neutrophils  std_item_51265_Platelet_Count  \
# count                    6.000000                      15.000000
# mean                     6.530005                      54.635029
# std                      4.220080                      46.518162
# min                      1.792577                      16.202214
# 25%                      3.342667                      28.176753
# 50%                      6.191047                      42.362672
# 75%                      8.748802                      52.102988
# max                     13.010765                     192.629103
#
#        std_item_51274_PT  std_item_51275_PTT  std_item_51277_RDW  \
# count          14.000000           14.000000           15.000000
# mean            1.916068           10.803080            0.388835
# std             1.565915           10.070460            0.216628
# min             0.282843            1.305435            0.180787
# 25%             0.801653            2.516722            0.237107
# 50%             1.396053            6.819204            0.321906
# 75%             2.382681           18.567885            0.453849
# max             4.843386           28.621427            0.956591
#
#        std_item_51279_Red_Blood_Cells  std_item_51301_White_Blood_Cells  \
# count                       15.000000                         15.000000
# mean                         0.329548                          2.908617
# std                          0.105034                          1.342626
# min                          0.171330                          0.837627
# 25%                          0.276261                          2.024934
# 50%                          0.325521                          3.051706
# 75%                          0.387411                          3.419497
# max                          0.533937                          6.419289
#
#        std_item_51678_L  std_item_52172_RDW-SD
# count          5.000000               7.000000
# mean           4.637135               1.177630
# std            3.501656               0.552822
# min            2.380740               0.412501
# 25%            2.412731               0.888626
# 50%            2.427815               1.098512
# 75%            5.558647               1.421400
# max           10.405740               2.112347
#
# [8 rows x 116 columns]

# %%
df_microb = pd.read_csv(URL_DATA+'hosp/microbiologyevents.csv.gz')


df = pd.merge(df_timeseries_patient,df_microb)

# %%
for comment in df.comments.unique():
    print(comment)
# Out:
# NO GROWTH.
# No MRSA isolated.
# NO STAPHYLOCOCCUS AUREUS ISOLATED.
# nan
# 2+   (1-5 per 1000X FIELD):   POLYMORPHONUCLEAR LEUKOCYTES.  NO MICROORGANISMS SEEN.
# NO POLYMORPHONUCLEAR LEUKOCYTES SEEN.  NO MICROORGANISMS SEEN.
# MIXED BACTERIAL FLORA ( >= 3 COLONY TYPES), CONSISTENT WITH SKIN AND/OR GENITAL CONTAMINATION.
# 2+   (1-5 per 1000X FIELD):   POLYMORPHONUCLEAR LEUKOCYTES.  NO MICROORGANISMS SEEN.  This is a concentrated smear made by cytospin method, please refer to hematology for a quantitative white blood cell count.
# ___
# MIXED BACTERIAL FLORA ( >= 3 COLONY TYPES), CONSISTENT WITH FECAL CONTAMINATION.
# NEGATIVE FOR LEGIONELLA SEROGROUP 1 ANTIGEN.            (Reference Range-Negative).  Performed by Immunochromogenic assay.  A negative result does not rule out infection due to other L. pneumophila serogroups or other Legionella species. Furthermore, in infected patients the excretion of antigen in urine may vary.
# NO MYCOBACTERIA ISOLATED.
# NO FUNGUS ISOLATED.
# <10,000 organisms/ml.
# CMV DNA not detected.  Performed by ___ CMV Test.  Linear range of quantification: 137 IU/mL - 9,100,000 IU/mL.  Limit of detection 91 IU/mL.  This test has been verified for use in the ___ patient population.
# NO ANAEROBES ISOLATED.
# 4+   (>10 per 1000X FIELD):   POLYMORPHONUCLEAR LEUKOCYTES.  NO MICROORGANISMS SEEN.  This is a concentrated smear made by cytospin method, please refer to hematology for a quantitative white blood cell count.
# NONREACTIVE.  Reference Range: Non-Reactive.
# NO POLYMORPHONUCLEAR LEUKOCYTES SEEN.  NO MICROORGANISMS SEEN.  This is a concentrated smear made by cytospin method, please refer to hematology for a quantitative white blood cell count.
# >25 PMNs and <10 epithelial cells/100X field.  NO MICROORGANISMS SEEN.
# RARE GROWTH Commensal Respiratory Flora.
# Commensal Respiratory Flora Absent.
# 1+    (<1 per 1000X FIELD):   POLYMORPHONUCLEAR LEUKOCYTES.  NO MICROORGANISMS SEEN.
# Mixed bacterial flora-culture screened for B. fragilis, C. perfringens, and C. septicum.
# This culture contains mixed bacterial types (>=3) so an abbreviated workup is performed. Any growth of P.aeruginosa, S.aureus and beta hemolytic streptococci will be reported. IF THESE BACTERIA ARE NOT REPORTED, THEY ARE NOT PRESENT in this culture.
# NO ACID FAST BACILLI SEEN ON CONCENTRATED SMEAR.
# 3+  (5-10 per 1000X FIELD):   POLYMORPHONUCLEAR LEUKOCYTES.  NO MICROORGANISMS SEEN.
# NO LEGIONELLA ISOLATED.
# Negative for toxigenic C. difficile by the Illumigene DNA amplification assay.            (Reference Range-Negative).
# No VRE isolated.
# NO GROWTH, <1000 CFU/ml.
# NEGATIVE <1:10 BY IFA.  INTERPRETATION: RESULTS INDICATIVE OF PAST EBV INFECTION.  In most populations, 90% of adults have been infected at sometime with EBV and will have measurable VCA IgG and EBNA antibodies. Antibodies to EBNA develop 6-8 weeks after primary infection and remain present for life. Presence of VCA IgM antibodies indicates recent primary infection.
# POSITIVE BY EIA.
# No respiratory viruses isolated.  Culture screened for Adenovirus, Influenza A & B, Parainfluenza type 1,2 & 3, and Respiratory Syncytial Virus.  Detection of viruses other than those listed above will only be performed on specific request. Please call Virology at ___ within 1 week if additional testing is needed.
# Negative for Respiratory Viral Antigen.  Specimen screened for: Adeno, Parainfluenza 1, 2, 3, Influenza A, B, and RSV by immunofluorescence.  Refer to respiratory viral culture and/or Influenza PCR (results listed under "OTHER" tab) for further information.
# NEGATIVE BY EIA.            (Reference Range-Negative).
# NEGATIVE BY EIA.            (Reference Range-Negative).  Negative results do not rule out B. burgdorferi infection.  Patients in early stages of infection or on antibiotic therapy may not produce  detectable levels of antibody
# NO VIRUS ISOLATED.
# MODERATE GROWTH Commensal Respiratory Flora.
# HCV-RNA NOT DETECTED.  Performed using ___ HCV v2.0 Test.  Linear range of quantification: 1.50E+01 IU/mL - 1.00E+08 IU/mL.  Limit of detection: 1.50E+01 IU/mL.
# HBV DNA not detected.  Performed using the ___ HBV Test v2.0.  Linear range of quantification: 20 IU/mL - 170 million IU/mL.  Limit of detection: 20 IU/mL.
# NEGATIVE FOR CMV IgM ANTIBODY BY EIA.  INTERPRETATION:  NO ANTIBODY DETECTED.  Greatly elevated serum protein with IgG levels >2000 mg/dl may cause  interference with CMV IgM results.
# NEGATIVE FOR CMV IgG ANTIBODY BY EIA.  <4 AU/ML.  Reference Range:  Negative < 4 AU/ml, Positive >= 6 AU/ml.
# TEST CANCELLED, PATIENT CREDITED.
# NEGATIVE FOR CMV IgM ANTIBODY BY EIA.  INTERPRETATION:  INFECTION AT UNDETERMINED TIME.  A positive IgG result generally indicates past exposure.  Infection with CMV once contracted remains latent and may reactivate when immunity is compromised.  Greatly elevated serum protein with IgG levels >2000 mg/dl may cause  interference with CMV IgM results.  If current infection is suspected, submit follow-up serum in 2-3 weeks.
# POSITIVE BY EIA.  A positive IgG result generally indicates past exposure and/or immunity.
# No Cytomegalovirus (CMV) isolated.
# NEGATIVE for Pneumocystis jirovecii (carinii).
# Negative for Cytomegalovirus early antigen by immunofluorescence.  Refer to culture results for further information.
# 10,000-100,000 ORGANISMS/ML. Commensal Respiratory Flora.
# Test cancelled by laboratory.  PATIENT CREDITED.  This is a low yield procedure based on our in-house studies.  if pulmonary Histoplasmosis, Coccidioidomycosis, Blastomycosis, Aspergillosis or Mucormycosis is strongly suspected, contact the Microbiology Laboratory (___).
# 1+    (<1 per 1000X FIELD):   POLYMORPHONUCLEAR LEUKOCYTES.  NO MICROORGANISMS SEEN.  SMEAR REVIEWED; RESULTS CONFIRMED.
# Negative for toxigenic C. difficile by the Cepheid nucleic acid amplification assay.            (Reference Range-Negative).
# NO CAMPYLOBACTER FOUND.
# NO SALMONELLA OR SHIGELLA FOUND.
# < 10,000 CFU/mL.
# <10 PMNs and >10 epithelial cells/100X field.  Gram stain indicates extensive contamination with upper respiratory secretions. Bacterial culture results are invalid.  PLEASE SUBMIT ANOTHER SPECIMEN.
# NO NOCARDIA ISOLATED.
# CRYPTOCOCCAL ANTIGEN NOT DETECTED.            (Reference Range-Negative).  Test performed by Lateral Flow Assay.  A negative serum does not rule out localized or disseminated cryptococcal infection.  Appropriate specimens should be sent for culture.
# 2+   (1-5 per 1000X FIELD):   POLYMORPHONUCLEAR LEUKOCYTES.  NO MICROORGANISMS SEEN.  SMEAR REVIEWED; RESULTS CONFIRMED.
# >100,000 CFU/mL Commensal Respiratory Flora.
# 10,000-100,000 CFU/mL Commensal Respiratory Flora.
# No Enterovirus isolated.
# NO ACID FAST BACILLI SEEN ON DIRECT SMEAR.
# 4+   (>10 per 1000X FIELD):   POLYMORPHONUCLEAR LEUKOCYTES.  NO MICROORGANISMS SEEN.
# 1+    (<1 per 1000X FIELD):   POLYMORPHONUCLEAR LEUKOCYTES.  NO MICROORGANISMS SEEN.  This is a concentrated smear made by cytospin method, please refer to hematology for a quantitative white blood cell count.
# HEAVY GROWTH Commensal Respiratory Flora.

# %%
df_summary[df_summary['temporal_cluster'] == 1].drop(columns=['subject_id', 'temporal_cluster']).describe()
# Out:
#        approx_age     gender  num_diagnoses  length_of_stay  died_in_hospital  \
# count   31.000000  31.000000      31.000000       31.000000         31.000000
# mean    59.032258   0.612903      19.895509       10.417133          0.116225
# std     13.382785   0.495138       7.504319        6.710197          0.240341
# min     28.000000   0.000000       5.414815        1.085417          0.000000
# 25%     52.500000   0.000000      15.067141        5.884925          0.000000
# 50%     63.000000   1.000000      20.452869        9.142300          0.000000
# 75%     66.500000   1.000000      25.394978       13.341938          0.000000
# max     80.000000   1.000000      32.850053       25.128521          0.800000
#
#        mean_item_50802_Base_Excess  mean_item_50804_Calculated_Total_CO2  \
# count                    24.000000                             24.000000
# mean                     -0.030778                             25.876236
# std                       4.107324                              4.964988
# min                      -9.636364                             15.181818
# 25%                      -1.146396                             23.402530
# 50%                       0.567761                             26.894594
# 75%                       2.518843                             29.313129
# max                       5.500000                             33.500000
#
#        mean_item_50808_Free_Calcium  mean_item_50809_Glucose  \
# count                     21.000000                14.000000
# mean                       1.132095               176.420727
# std                        0.066891                90.164820
# min                        0.983873                85.500000
# 25%                        1.093758               117.938758
# 50%                        1.146667               137.250000
# 75%                        1.174438               210.603198
# max                        1.282721               421.500000
#
#        mean_item_50813_Lactate  ...  std_item_51254_Monocytes  \
# count                24.000000  ...                 17.000000
# mean                  1.704226  ...                  2.261599
# std                   0.541810  ...                  1.795589
# min                   0.871970  ...                  0.070711
# 25%                   1.273053  ...                  0.909303
# 50%                   1.671574  ...                  1.889509
# 75%                   1.981147  ...                  3.929695
# max                   3.136537  ...                  5.338321
#
#        std_item_51256_Neutrophils  std_item_51265_Platelet_Count  \
# count                   17.000000                      30.000000
# mean                     8.365036                      41.911637
# std                      5.307938                      22.420429
# min                      2.192031                       8.888194
# 25%                      4.357752                      26.451087
# 50%                      7.032087                      36.768073
# 75%                     12.162237                      55.598134
# max                     21.175012                      85.502713
#
#        std_item_51274_PT  std_item_51275_PTT  std_item_51277_RDW  \
# count          29.000000           29.000000           30.000000
# mean            1.901832            7.845806            0.427319
# std             1.853187            9.861048            0.283288
# min             0.214851            0.636396            0.035613
# 25%             0.707476            1.739184            0.216834
# 50%             1.102112            3.061046            0.328455
# 75%             2.211334           10.816337            0.568870
# max             6.969336           41.389591            1.167176
#
#        std_item_51279_Red_Blood_Cells  std_item_51301_White_Blood_Cells  \
# count                       30.000000                         30.000000
# mean                         0.240020                          3.247247
# std                          0.076919                          4.508415
# min                          0.119795                          0.200000
# 25%                          0.180859                          1.592756
# 50%                          0.235388                          2.092707
# 75%                          0.283911                          2.844728
# max                          0.398089                         25.023803
#
#        std_item_51678_L  std_item_52172_RDW-SD
# count         18.000000              22.000000
# mean           5.576178               1.641941
# std            4.950002               0.924204
# min            0.707107               0.282843
# 25%            3.017714               0.997179
# 50%            4.240249               1.378124
# 75%            5.970311               2.187674
# max           22.041718               4.203673
#
# [8 rows x 116 columns]
